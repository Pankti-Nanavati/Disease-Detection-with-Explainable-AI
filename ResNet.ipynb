# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import cv2
import os
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, Input, load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/final_year_project_dataset')

# %%
disease_types=['COVID', 'non-COVID']
data_dir = ''
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])
        
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])
train.head()
# Out:
#                     File  DiseaseID Disease Type
# 0  COVID/Covid (695).png          0        COVID
# 1  COVID/Covid (717).png          0        COVID
# 2  COVID/Covid (739).png          0        COVID
# 3  COVID/Covid (760).png          0        COVID
# 4  COVID/Covid (705).png          0        COVID

# %%
SEED = 42
train = train.sample(frac=1, random_state=SEED) 
train.index = np.arange(len(train)) # Reset indices
train.head()
# Out:
#                      File  DiseaseID Disease Type
# 0  COVID/Covid (1152).png          0        COVID
# 1   COVID/Covid (516).png          0        COVID
# 2    COVID/Covid (95).png          0        COVID
# 3   COVID/Covid (860).png          0        COVID
# 4   COVID/Covid (692).png          0        COVID

# %%
#import pandas_profiling as pp
#pp.ProfileReport(train)

# %%
plt.hist(train['DiseaseID'])
plt.title('Frequency Histogram of Species')
plt.figure(figsize=(12, 12))
plt.show()

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) # Loading a color image is the default flag
# Resize image to target size
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
# Normalize the data
X_Train = X_train / 255.
print('Train Shape: {}'.format(X_Train.shape))
# Out:
# 2513it [04:14,  9.86it/s]
# Train Shape: (2513, 64, 64, 3)

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            
            n += 1
# Displays first n images of class from training set
plot_defects('non-COVID', 3, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)
print(Y_train.shape)
# Out:
# (2513, 2)

# %%
BATCH_SIZE = 64

# Split the train and validation sets 
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state=SEED)

# %%
print(f'X_train:',X_train.shape)
print(f'X_val:',X_val.shape)
print(f'Y_train:',Y_train.shape)
print(f'Y_val:',Y_val.shape)
# Out:
# X_train: (2010, 64, 64, 3)
# X_val: (503, 64, 64, 3)
# Y_train: (2010, 2)
# Y_val: (503, 2)

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    n = 0
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1
# Displays first n images of class from training set
plot_defects('COVID', 3, 3)

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 15))
for i in range(3):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(disease_types[np.argmax(Y_train[i])])

# %%
EPOCHS = 50
SIZE=64
N_ch=3

# %%
def build_resnet50():
    resnet50 = ResNet50(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = resnet50(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.003, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
model = build_resnet50()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.70, patience=5, verbose=1, min_lr=1e-4)
checkpoint = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)
# Generates batches of image data with data augmentation
datagen = ImageDataGenerator(rotation_range=360, # Degree range for random rotations
                        width_shift_range=0.2, # Range for random horizontal shifts
                        height_shift_range=0.2, # Range for random vertical shifts
                        zoom_range=0.2, # Range for random zoom
                        horizontal_flip=True, # Randomly flip inputs horizontally
                        vertical_flip=True) # Randomly flip inputs vertically

datagen.fit(X_train)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 3)         84
#
#  resnet50 (Functional)       (None, None, None, 2048)  23587712
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  root (Dense)                (None, 2)                 514
#
# =================================================================
# Total params: 24,122,070
# Trainable params: 24,064,342
# Non-trainable params: 57,728
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='convnet.png', show_shapes=True,show_layer_names=True)
Image(filename='convnet.png')

# %%
# Fits the model on batches with real-time data augmentation
hist = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/50
# 31/31 [==============================] - ETA: 0s - loss: 1.1733 - accuracy: 0.5313
# Epoch 00001: val_loss improved from inf to 0.99531, saving model to model.h5
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# 31/31 [==============================] - 342s 11s/step - loss: 1.1733 - accuracy: 0.5313 - val_loss: 0.9953 - val_accuracy: 0.4970 - lr: 0.0030
# Epoch 2/50
# 31/31 [==============================] - ETA: 0s - loss: 0.9912 - accuracy: 0.5987
# Epoch 00002: val_loss improved from 0.99531 to 0.78506, saving model to model.h5
# 31/31 [==============================] - 342s 11s/step - loss: 0.9912 - accuracy: 0.5987 - val_loss: 0.7851 - val_accuracy: 0.4970 - lr: 0.0030
# Epoch 3/50
# 31/31 [==============================] - ETA: 0s - loss: 0.9410 - accuracy: 0.6274
# Epoch 00003: val_loss did not improve from 0.78506
# 31/31 [==============================] - 333s 11s/step - loss: 0.9410 - accuracy: 0.6274 - val_loss: 0.7908 - val_accuracy: 0.4970 - lr: 0.0030
# Epoch 4/50
# 31/31 [==============================] - ETA: 0s - loss: 0.8399 - accuracy: 0.6413
# Epoch 00004: val_loss did not improve from 0.78506
# 31/31 [==============================] - 302s 10s/step - loss: 0.8399 - accuracy: 0.6413 - val_loss: 0.8374 - val_accuracy: 0.4970 - lr: 0.0030
# Epoch 5/50
# 31/31 [==============================] - ETA: 0s - loss: 0.7851 - accuracy: 0.6470
# Epoch 00005: val_loss did not improve from 0.78506
# 31/31 [==============================] - 301s 10s/step - loss: 0.7851 - accuracy: 0.6470 - val_loss: 1.9774 - val_accuracy: 0.4970 - lr: 0.0030
# Epoch 6/50
# 31/31 [==============================] - ETA: 0s - loss: 0.6594 - accuracy: 0.7122
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.002100000018253922.
#
# Epoch 00006: val_loss did not improve from 0.78506
# 31/31 [==============================] - 275s 9s/step - loss: 0.6594 - accuracy: 0.7122 - val_loss: 2.1830 - val_accuracy: 0.4970 - lr: 0.0030
# Epoch 7/50
# 31/31 [==============================] - ETA: 0s - loss: 0.6187 - accuracy: 0.7282
# Epoch 00007: val_loss improved from 0.78506 to 0.77286, saving model to model.h5
# 31/31 [==============================] - 289s 9s/step - loss: 0.6187 - accuracy: 0.7282 - val_loss: 0.7729 - val_accuracy: 0.4970 - lr: 0.0021
# Epoch 8/50
# 31/31 [==============================] - ETA: 0s - loss: 0.5709 - accuracy: 0.7261
# Epoch 00008: val_loss improved from 0.77286 to 0.72602, saving model to model.h5
# 31/31 [==============================] - 294s 9s/step - loss: 0.5709 - accuracy: 0.7261 - val_loss: 0.7260 - val_accuracy: 0.4970 - lr: 0.0021
# Epoch 9/50
# 31/31 [==============================] - ETA: 0s - loss: 0.5189 - accuracy: 0.7677
# Epoch 00009: val_loss did not improve from 0.72602
# 31/31 [==============================] - 304s 10s/step - loss: 0.5189 - accuracy: 0.7677 - val_loss: 1.0309 - val_accuracy: 0.4970 - lr: 0.0021
# Epoch 10/50
# 31/31 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.7939
# Epoch 00010: val_loss did not improve from 0.72602
# 31/31 [==============================] - 337s 11s/step - loss: 0.4637 - accuracy: 0.7939 - val_loss: 1.3224 - val_accuracy: 0.4970 - lr: 0.0021
# Epoch 11/50
# 31/31 [==============================] - ETA: 0s - loss: 0.4401 - accuracy: 0.8155
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0014699999475851653.
#
# Epoch 00011: val_loss did not improve from 0.72602
# 31/31 [==============================] - 339s 11s/step - loss: 0.4401 - accuracy: 0.8155 - val_loss: 1.5799 - val_accuracy: 0.4970 - lr: 0.0021
# Epoch 12/50
# 31/31 [==============================] - ETA: 0s - loss: 0.4428 - accuracy: 0.7986
# Epoch 00012: val_loss did not improve from 0.72602
# 31/31 [==============================] - 346s 11s/step - loss: 0.4428 - accuracy: 0.7986 - val_loss: 2.0622 - val_accuracy: 0.4970 - lr: 0.0015
# Epoch 13/50
# 31/31 [==============================] - ETA: 0s - loss: 0.4437 - accuracy: 0.8011
# Epoch 00013: val_loss did not improve from 0.72602
# 31/31 [==============================] - 343s 11s/step - loss: 0.4437 - accuracy: 0.8011 - val_loss: 1.9446 - val_accuracy: 0.4970 - lr: 0.0015
# Epoch 14/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3987 - accuracy: 0.8299
# Epoch 00014: val_loss did not improve from 0.72602
# 31/31 [==============================] - 312s 10s/step - loss: 0.3987 - accuracy: 0.8299 - val_loss: 2.0194 - val_accuracy: 0.4970 - lr: 0.0015
# Epoch 15/50
# 31/31 [==============================] - ETA: 0s - loss: 0.4036 - accuracy: 0.8226
# Epoch 00015: val_loss did not improve from 0.72602
# 31/31 [==============================] - 318s 10s/step - loss: 0.4036 - accuracy: 0.8226 - val_loss: 1.3575 - val_accuracy: 0.4970 - lr: 0.0015
# Epoch 16/50
# 31/31 [==============================] - ETA: 0s - loss: 0.4020 - accuracy: 0.8222
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0010289999307133257.
#
# Epoch 00016: val_loss did not improve from 0.72602
# 31/31 [==============================] - 318s 10s/step - loss: 0.4020 - accuracy: 0.8222 - val_loss: 1.5433 - val_accuracy: 0.4970 - lr: 0.0015
# Epoch 17/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3708 - accuracy: 0.8448
# Epoch 00017: val_loss did not improve from 0.72602
# 31/31 [==============================] - 332s 11s/step - loss: 0.3708 - accuracy: 0.8448 - val_loss: 1.5091 - val_accuracy: 0.4970 - lr: 0.0010
# Epoch 18/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3807 - accuracy: 0.8474
# Epoch 00018: val_loss did not improve from 0.72602
# 31/31 [==============================] - 344s 11s/step - loss: 0.3807 - accuracy: 0.8474 - val_loss: 1.3813 - val_accuracy: 0.4970 - lr: 0.0010
# Epoch 19/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3647 - accuracy: 0.8551
# Epoch 00019: val_loss did not improve from 0.72602
# 31/31 [==============================] - 346s 11s/step - loss: 0.3647 - accuracy: 0.8551 - val_loss: 1.2484 - val_accuracy: 0.4970 - lr: 0.0010
# Epoch 20/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3585 - accuracy: 0.8515
# Epoch 00020: val_loss did not improve from 0.72602
# 31/31 [==============================] - 334s 11s/step - loss: 0.3585 - accuracy: 0.8515 - val_loss: 1.0417 - val_accuracy: 0.4970 - lr: 0.0010
# Epoch 21/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3482 - accuracy: 0.8520
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0007202999433502554.
#
# Epoch 00021: val_loss did not improve from 0.72602
# 31/31 [==============================] - 336s 11s/step - loss: 0.3482 - accuracy: 0.8520 - val_loss: 0.9144 - val_accuracy: 0.4970 - lr: 0.0010
# Epoch 22/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3692 - accuracy: 0.8479
# Epoch 00022: val_loss did not improve from 0.72602
# 31/31 [==============================] - 342s 11s/step - loss: 0.3692 - accuracy: 0.8479 - val_loss: 0.7960 - val_accuracy: 0.4930 - lr: 7.2030e-04
# Epoch 23/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3560 - accuracy: 0.8443
# Epoch 00023: val_loss improved from 0.72602 to 0.63822, saving model to model.h5
# 31/31 [==============================] - 342s 11s/step - loss: 0.3560 - accuracy: 0.8443 - val_loss: 0.6382 - val_accuracy: 0.6064 - lr: 7.2030e-04
# Epoch 24/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3384 - accuracy: 0.8494
# Epoch 00024: val_loss improved from 0.63822 to 0.55138, saving model to model.h5
# 31/31 [==============================] - 340s 11s/step - loss: 0.3384 - accuracy: 0.8494 - val_loss: 0.5514 - val_accuracy: 0.6819 - lr: 7.2030e-04
# Epoch 25/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3406 - accuracy: 0.8597
# Epoch 00025: val_loss improved from 0.55138 to 0.49978, saving model to model.h5
# 31/31 [==============================] - 335s 11s/step - loss: 0.3406 - accuracy: 0.8597 - val_loss: 0.4998 - val_accuracy: 0.7177 - lr: 7.2030e-04
# Epoch 26/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8597
# Epoch 00026: val_loss did not improve from 0.49978
# 31/31 [==============================] - 327s 11s/step - loss: 0.3327 - accuracy: 0.8597 - val_loss: 0.5027 - val_accuracy: 0.7256 - lr: 7.2030e-04
# Epoch 27/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3303 - accuracy: 0.8587
# Epoch 00027: val_loss did not improve from 0.49978
# 31/31 [==============================] - 327s 11s/step - loss: 0.3303 - accuracy: 0.8587 - val_loss: 0.5158 - val_accuracy: 0.7356 - lr: 7.2030e-04
# Epoch 28/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3402 - accuracy: 0.8577
# Epoch 00028: val_loss did not improve from 0.49978
# 31/31 [==============================] - 335s 11s/step - loss: 0.3402 - accuracy: 0.8577 - val_loss: 0.5395 - val_accuracy: 0.7316 - lr: 7.2030e-04
# Epoch 29/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3220 - accuracy: 0.8638
# Epoch 00029: val_loss did not improve from 0.49978
# 31/31 [==============================] - 328s 11s/step - loss: 0.3220 - accuracy: 0.8638 - val_loss: 0.5811 - val_accuracy: 0.7237 - lr: 7.2030e-04
# Epoch 30/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3271 - accuracy: 0.8592
# Epoch 00030: val_loss did not improve from 0.49978
# 31/31 [==============================] - 249s 8s/step - loss: 0.3271 - accuracy: 0.8592 - val_loss: 0.6516 - val_accuracy: 0.7137 - lr: 7.2030e-04
# Epoch 31/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3250 - accuracy: 0.8659
# Epoch 00031: val_loss did not improve from 0.49978
# 31/31 [==============================] - 249s 8s/step - loss: 0.3250 - accuracy: 0.8659 - val_loss: 0.6661 - val_accuracy: 0.7097 - lr: 7.2030e-04
# Epoch 32/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3080 - accuracy: 0.8777
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0005042099684942513.
#
# Epoch 00032: val_loss did not improve from 0.49978
# 31/31 [==============================] - 257s 8s/step - loss: 0.3080 - accuracy: 0.8777 - val_loss: 0.6776 - val_accuracy: 0.7097 - lr: 7.2030e-04
# Epoch 33/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.8710
# Epoch 00033: val_loss did not improve from 0.49978
# 31/31 [==============================] - 268s 9s/step - loss: 0.3265 - accuracy: 0.8710 - val_loss: 0.5946 - val_accuracy: 0.7376 - lr: 5.0421e-04
# Epoch 34/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3149 - accuracy: 0.8679
# Epoch 00034: val_loss did not improve from 0.49978
# 31/31 [==============================] - 258s 8s/step - loss: 0.3149 - accuracy: 0.8679 - val_loss: 0.5321 - val_accuracy: 0.7575 - lr: 5.0421e-04
# Epoch 35/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3157 - accuracy: 0.8756
# Epoch 00035: val_loss did not improve from 0.49978
# 31/31 [==============================] - 255s 8s/step - loss: 0.3157 - accuracy: 0.8756 - val_loss: 0.5437 - val_accuracy: 0.7594 - lr: 5.0421e-04
# Epoch 36/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3051 - accuracy: 0.8746
# Epoch 00036: val_loss did not improve from 0.49978
# 31/31 [==============================] - 259s 8s/step - loss: 0.3051 - accuracy: 0.8746 - val_loss: 0.5263 - val_accuracy: 0.7694 - lr: 5.0421e-04
# Epoch 37/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3038 - accuracy: 0.8792
# Epoch 00037: val_loss improved from 0.49978 to 0.43668, saving model to model.h5
# 31/31 [==============================] - 268s 9s/step - loss: 0.3038 - accuracy: 0.8792 - val_loss: 0.4367 - val_accuracy: 0.8032 - lr: 5.0421e-04
# Epoch 38/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.8674
# Epoch 00038: val_loss improved from 0.43668 to 0.41908, saving model to model.h5
# 31/31 [==============================] - 258s 8s/step - loss: 0.3293 - accuracy: 0.8674 - val_loss: 0.4191 - val_accuracy: 0.8171 - lr: 5.0421e-04
# Epoch 39/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.8741
# Epoch 00039: val_loss improved from 0.41908 to 0.36223, saving model to model.h5
# 31/31 [==============================] - 254s 8s/step - loss: 0.3117 - accuracy: 0.8741 - val_loss: 0.3622 - val_accuracy: 0.8529 - lr: 5.0421e-04
# Epoch 40/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2958 - accuracy: 0.8859
# Epoch 00040: val_loss improved from 0.36223 to 0.30364, saving model to model.h5
# 31/31 [==============================] - 254s 8s/step - loss: 0.2958 - accuracy: 0.8859 - val_loss: 0.3036 - val_accuracy: 0.8847 - lr: 5.0421e-04
# Epoch 41/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3193 - accuracy: 0.8674
# Epoch 00041: val_loss did not improve from 0.30364
# 31/31 [==============================] - 249s 8s/step - loss: 0.3193 - accuracy: 0.8674 - val_loss: 0.3091 - val_accuracy: 0.8807 - lr: 5.0421e-04
# Epoch 42/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3061 - accuracy: 0.8813
# Epoch 00042: val_loss improved from 0.30364 to 0.30205, saving model to model.h5
# 31/31 [==============================] - 257s 8s/step - loss: 0.3061 - accuracy: 0.8813 - val_loss: 0.3020 - val_accuracy: 0.8767 - lr: 5.0421e-04
# Epoch 43/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.8710
# Epoch 00043: val_loss improved from 0.30205 to 0.28517, saving model to model.h5
# 31/31 [==============================] - 253s 8s/step - loss: 0.3125 - accuracy: 0.8710 - val_loss: 0.2852 - val_accuracy: 0.8867 - lr: 5.0421e-04
# Epoch 44/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3030 - accuracy: 0.8803
# Epoch 00044: val_loss improved from 0.28517 to 0.28316, saving model to model.h5
# 31/31 [==============================] - 253s 8s/step - loss: 0.3030 - accuracy: 0.8803 - val_loss: 0.2832 - val_accuracy: 0.8847 - lr: 5.0421e-04
# Epoch 45/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.8844
# Epoch 00045: val_loss did not improve from 0.28316
# 31/31 [==============================] - 250s 8s/step - loss: 0.2885 - accuracy: 0.8844 - val_loss: 0.3426 - val_accuracy: 0.8807 - lr: 5.0421e-04
# Epoch 46/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2863 - accuracy: 0.8844
# Epoch 00046: val_loss did not improve from 0.28316
# 31/31 [==============================] - 247s 8s/step - loss: 0.2863 - accuracy: 0.8844 - val_loss: 0.3116 - val_accuracy: 0.9006 - lr: 5.0421e-04
# Epoch 47/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.8684
# Epoch 00047: val_loss did not improve from 0.28316
# 31/31 [==============================] - 246s 8s/step - loss: 0.3005 - accuracy: 0.8684 - val_loss: 0.2984 - val_accuracy: 0.8986 - lr: 5.0421e-04
# Epoch 48/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2888 - accuracy: 0.8780
# Epoch 00048: val_loss did not improve from 0.28316
# 31/31 [==============================] - 249s 8s/step - loss: 0.2888 - accuracy: 0.8780 - val_loss: 0.3403 - val_accuracy: 0.8827 - lr: 5.0421e-04
# Epoch 49/50
# 31/31 [==============================] - ETA: 0s - loss: 0.2996 - accuracy: 0.8751
# Epoch 00049: val_loss did not improve from 0.28316
# 31/31 [==============================] - 249s 8s/step - loss: 0.2996 - accuracy: 0.8751 - val_loss: 0.3141 - val_accuracy: 0.8986 - lr: 5.0421e-04
# Epoch 50/50
# 31/31 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.8684
# Epoch 00050: val_loss did not improve from 0.28316
# 31/31 [==============================] - 248s 8s/step - loss: 0.3064 - accuracy: 0.8684 - val_loss: 0.2934 - val_accuracy: 0.8946 - lr: 5.0421e-04

# %%
from sklearn.metrics import confusion_matrix
#model = load_model('../output/kaggle/working/model.h5')
final_loss, final_accuracy = model.evaluate(X_val, Y_val)
print('Final Loss: {}, Final Accuracy: {}'.format(final_loss, final_accuracy))
# Out:
# 16/16 [==============================] - 6s 386ms/step - loss: 0.2934 - accuracy: 0.8946
# Final Loss: 0.29338300228118896, Final Accuracy: 0.8946322202682495

# %%
Y_pred = model.predict(X_val)

Y_pred = np.argmax(Y_pred, axis=1)
Y_true = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_true, Y_pred)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)
# Out:
# Text(0.5, 145.31999999999996, 'Predicted')

# %%
# accuracy plot 
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# loss plot
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from skimage import io
from keras.preprocessing import image
img = image.load_img('/content/drive/My Drive/final_year_project_dataset/COVID/Covid (1248).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/drive/My Drive/final_year_project_dataset/COVID/Covid (1248).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [0.97161174 0.02838831]
# Prediction: Covid-19

# %%
from skimage import io
from keras.preprocessing import image
img = image.load_img('/content/drive/My Drive/final_year_project_dataset/non-COVID/Non-Covid (1181).png', grayscale=False, target_size=(64, 64))
show_img=image.load_img('/content/drive/My Drive/final_year_project_dataset/non-COVID/Non-Covid (1181).png', grayscale=False, target_size=(200, 200))
disease_class=['Covid-19','Non Covid-19']
x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)
x /= 255

custom = model.predict(x)
print(custom[0])

plt.imshow(show_img)
plt.show()

a=custom[0]
ind=np.argmax(a)
        
print('Prediction:',disease_class[ind])
# Out:
# [0.03953076 0.96046925]
# Prediction: Non Covid-19
